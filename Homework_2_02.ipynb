# %%
import pandas as pd
import numpy as np

# %%
PerformanceColumnNames = (
    "LOAN_ID", "Monthly.Rpt.Prd", "Servicer.Name", 
    "LAST_RT", "LAST_UPB", "Loan.Age", "Months.To.Legal.Mat", 
    "Adj.Month.To.Mat", "Maturity.Date", "MSA", 
    "Delq.Status", "MOD_FLAG", "Zero.Bal.Code", 
    "ZB_DTE", "LPI_DTE", "FCC_DTE","DISP_DT", 
    "FCC_COST", "PP_COST", "AR_COST", "IE_COST", 
    "TAX_COST", "NS_PROCS","CE_PROCS", "RMW_PROCS", 
    "O_PROCS", "NON_INT_UPB", "PRIN_FORG_UPB_FHFA", 
    "REPCH_FLAG", "PRIN_FORG_UPB_OTH", "TRANSFER_FLG"
)

# %%
performance_df = pd.read_csv(r'C:\Users\alpal\Desktop\FE-690\Mortgage Data\Performance_2010Q1.txt',
                    names=PerformanceColumnNames,
                    header=None,
                    sep="|"
)
# Out:
# C:\Users\alpal\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
performance_df.head()
# Out:
#         LOAN_ID Monthly.Rpt.Prd           Servicer.Name  LAST_RT  LAST_UPB  \
# 0  100010079393      02/01/2010  WELLS FARGO BANK, N.A.    4.875       NaN
# 1  100010079393      03/01/2010                     NaN    4.875       NaN
# 2  100010079393      04/01/2010                     NaN    4.875       NaN
# 3  100010079393      05/01/2010                     NaN    4.875       NaN
# 4  100010079393      06/01/2010                     NaN    4.875       NaN
#
#    Loan.Age  Months.To.Legal.Mat  Adj.Month.To.Mat Maturity.Date    MSA  ...  \
# 0         0                  360             360.0       02/2040  12420  ...
# 1         1                  359             358.0       02/2040  12420  ...
# 2         2                  358             358.0       02/2040  12420  ...
# 3         3                  357             357.0       02/2040  12420  ...
# 4         4                  356             355.0       02/2040  12420  ...
#
#   TAX_COST NS_PROCS  CE_PROCS RMW_PROCS O_PROCS NON_INT_UPB  \
# 0      NaN      NaN       NaN       NaN     NaN         NaN
# 1      NaN      NaN       NaN       NaN     NaN         NaN
# 2      NaN      NaN       NaN       NaN     NaN         NaN
# 3      NaN      NaN       NaN       NaN     NaN         NaN
# 4      NaN      NaN       NaN       NaN     NaN         NaN
#
#   PRIN_FORG_UPB_FHFA  REPCH_FLAG  PRIN_FORG_UPB_OTH  TRANSFER_FLG
# 0                NaN         NaN                NaN             N
# 1                NaN         NaN                NaN             N
# 2                NaN         NaN                NaN             N
# 3                NaN         NaN                NaN             N
# 4                NaN         NaN                NaN             N
#
# [5 rows x 31 columns]

# %% [markdown]
# __Still experiencing memory errors__

# %%
performance_df['Monthly.Rpt.Prd'] = pd.to_datetime(performance_df['Monthly.Rpt.Prd'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime._string_to_dts()
#
# ValueError: Error parsing datetime string "09/01/2013" at position 2
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-69e3fed152d6> in <module>
# ----> 1 performance_df['Monthly.Rpt.Prd'] = pd.to_datetime(performance_df['Monthly.Rpt.Prd'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     590         else:
#     591             from pandas import Series
# --> 592             values = convert_listlike(arg._values, True, format)
#     593             result = Series(values, index=arg.index, name=arg.name)
#     594     elif isinstance(arg, (ABCDataFrame, compat.MutableMapping)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     300             arg, dayfirst=dayfirst, yearfirst=yearfirst,
#     301             utc=utc, errors=errors, require_iso8601=require_iso8601,
# --> 302             allow_object=True)
#     303
#     304     if tz_parsed is not None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855             dayfirst=dayfirst,
#    1856             yearfirst=yearfirst,
# -> 1857             require_iso8601=require_iso8601
#    1858         )
#    1859     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     652             raise ValueError("String does not contain a date:", timestr)
#     653
# --> 654         ret = self._build_naive(res, default)
#     655
#     656         if not ignoretz:
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1229         naive = default.replace(**repl)
#    1230
# -> 1231         if res.weekday is not None and not res.day:
#    1232             naive = naive + relativedelta.relativedelta(weekday=res.weekday)
#    1233
#
# KeyboardInterrupt:

# %%
performance_train = performance_df[performance_df['Monthly.Rpt.Prd'] < '2015/01/01']
performance_test = performance_df[performance_df['Monthly.Rpt.Prd'] >= '2015/01/01']
